# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import randint
import warnings
warnings.filterwarnings('ignore')

# %%
test=randint(30,70,1000)
test
# Out:
# array([67, 37, 58, 30, 37, 30, 48, 42, 30, 56, 60, 46, 49, 32, 60, 55, 65,
#        66, 45, 56, 67, 52, 34, 46, 36, 46, 59, 48, 38, 64, 40, 48, 31, 68,
#        49, 41, 54, 52, 69, 61, 42, 61, 52, 60, 51, 44, 37, 54, 50, 57, 67,
#        31, 33, 66, 37, 53, 55, 32, 40, 67, 54, 56, 64, 59, 31, 42, 67, 56,
#        54, 69, 67, 37, 68, 34, 47, 68, 34, 59, 46, 37, 33, 67, 42, 35, 49,
#        66, 64, 69, 39, 50, 30, 47, 49, 55, 39, 40, 43, 41, 54, 38, 43, 37,
#        34, 53, 45, 60, 51, 51, 43, 30, 62, 61, 63, 40, 61, 58, 36, 65, 38,
#        68, 53, 45, 65, 60, 57, 48, 32, 44, 54, 32, 58, 55, 55, 42, 37, 46,
#        68, 51, 32, 39, 38, 55, 40, 46, 46, 30, 50, 66, 55, 31, 43, 61, 58,
#        46, 51, 58, 45, 36, 32, 32, 57, 50, 60, 49, 31, 36, 64, 51, 59, 61,
#        61, 41, 52, 30, 37, 38, 66, 32, 44, 46, 42, 53, 55, 62, 61, 47, 33,
#        59, 47, 46, 54, 60, 60, 38, 68, 64, 53, 35, 53, 38, 37, 40, 41, 48,
#        55, 64, 45, 32, 50, 51, 58, 45, 38, 60, 47, 30, 56, 46, 37, 56, 58,
#        67, 32, 68, 55, 54, 50, 32, 43, 69, 56, 60, 45, 56, 38, 35, 39, 50,
#        62, 45, 60, 65, 68, 44, 47, 42, 55, 65, 47, 30, 68, 37, 31, 35, 39,
#        53, 31, 52, 58, 38, 61, 31, 47, 51, 44, 33, 48, 54, 59, 56, 56, 59,
#        39, 43, 36, 53, 52, 38, 57, 48, 37, 34, 58, 66, 67, 39, 55, 35, 69,
#        41, 50, 53, 33, 53, 51, 40, 67, 39, 66, 44, 58, 61, 63, 60, 52, 37,
#        39, 53, 53, 46, 61, 62, 58, 64, 38, 37, 57, 56, 50, 34, 38, 56, 58,
#        58, 54, 48, 44, 50, 57, 36, 42, 33, 45, 58, 40, 43, 52, 41, 59, 46,
#        65, 69, 34, 31, 66, 61, 65, 42, 39, 37, 45, 33, 44, 61, 32, 39, 40,
#        49, 40, 35, 48, 50, 58, 48, 34, 39, 35, 30, 52, 68, 53, 44, 46, 61,
#        58, 43, 69, 61, 49, 54, 42, 48, 48, 47, 33, 69, 68, 37, 49, 34, 40,
#        61, 57, 49, 69, 51, 46, 63, 39, 55, 49, 48, 58, 68, 37, 43, 40, 48,
#        38, 66, 68, 52, 31, 40, 45, 54, 68, 68, 52, 53, 51, 30, 69, 65, 33,
#        69, 44, 61, 35, 58, 48, 51, 45, 42, 53, 49, 42, 35, 52, 45, 50, 67,
#        62, 51, 62, 56, 52, 53, 50, 50, 65, 41, 30, 66, 65, 48, 54, 63, 59,
#        54, 30, 43, 55, 50, 42, 50, 61, 37, 46, 35, 35, 39, 46, 57, 31, 54,
#        64, 44, 36, 61, 52, 46, 50, 45, 30, 67, 41, 45, 55, 63, 30, 45, 34,
#        36, 48, 44, 65, 64, 64, 46, 34, 61, 53, 47, 30, 64, 46, 38, 50, 53,
#        32, 53, 34, 63, 41, 66, 65, 32, 56, 61, 50, 31, 68, 57, 50, 42, 48,
#        54, 58, 35, 62, 46, 48, 65, 39, 45, 47, 51, 33, 37, 61, 51, 46, 54,
#        45, 63, 32, 52, 41, 66, 52, 40, 43, 66, 33, 42, 68, 46, 56, 52, 50,
#        68, 52, 57, 53, 53, 59, 52, 39, 34, 64, 32, 50, 47, 57, 41, 54, 39,
#        57, 34, 54, 44, 53, 39, 68, 52, 31, 48, 57, 37, 44, 56, 48, 59, 30,
#        50, 56, 33, 58, 47, 40, 66, 38, 58, 59, 38, 38, 31, 42, 40, 60, 43,
#        66, 35, 46, 56, 34, 43, 63, 38, 69, 42, 31, 69, 67, 42, 63, 57, 68,
#        33, 40, 67, 56, 48, 45, 56, 62, 51, 48, 32, 30, 48, 68, 35, 68, 55,
#        44, 43, 67, 38, 43, 58, 35, 41, 65, 37, 59, 57, 33, 44, 32, 53, 35,
#        41, 40, 41, 33, 34, 56, 55, 50, 58, 62, 68, 40, 69, 69, 53, 68, 64,
#        41, 48, 63, 60, 57, 48, 66, 41, 31, 52, 46, 68, 67, 48, 65, 39, 40,
#        35, 59, 69, 46, 48, 32, 50, 43, 34, 62, 64, 48, 54, 40, 37, 61, 36,
#        45, 61, 54, 43, 66, 43, 68, 48, 59, 60, 45, 55, 54, 37, 44, 45, 59,
#        36, 43, 60, 38, 37, 31, 33, 48, 66, 63, 67, 40, 33, 52, 34, 51, 67,
#        35, 52, 43, 46, 59, 59, 42, 33, 51, 51, 49, 37, 67, 44, 47, 58, 69,
#        62, 64, 51, 64, 44, 42, 58, 53, 40, 51, 59, 35, 37, 48, 68, 50, 64,
#        46, 48, 55, 43, 38, 60, 68, 46, 67, 51, 68, 51, 67, 63, 47, 51, 30,
#        50, 32, 34, 54, 66, 40, 49, 52, 50, 44, 67, 46, 44, 58, 32, 46, 69,
#        41, 44, 52, 32, 50, 55, 52, 57, 65, 36, 41, 46, 53, 60, 59, 52, 35,
#        56, 51, 46, 59, 41, 43, 44, 48, 45, 43, 51, 43, 54, 60, 57, 61, 35,
#        52, 33, 65, 58, 50, 33, 41, 58, 34, 32, 43, 65, 51, 57, 67, 64, 55,
#        65, 59, 54, 56, 42, 64, 46, 62, 69, 52, 59, 39, 32, 67, 67, 63, 31,
#        57, 37, 68, 48, 39, 62, 51, 52, 45, 65, 47, 68, 43, 35, 37, 62, 68,
#        45, 52, 54, 69, 58, 54, 53, 66, 51, 34, 64, 38, 41, 61, 51, 34, 51,
#        31, 67, 58, 37, 43, 60, 38, 46, 56, 33, 55, 44, 53, 58, 51, 43, 62,
#        31, 42, 66, 34, 33, 49, 62, 63, 40, 42, 30, 35, 34, 35, 69, 60, 54,
#        60, 62, 60, 46, 64, 45, 39, 42, 32, 45, 67, 65, 40, 59, 46, 35, 67,
#        33, 40, 30, 68, 33, 59, 56, 62, 61, 47, 35, 57, 45, 53, 68, 33, 49,
#        34, 50, 62, 61, 55, 51, 56, 57, 35, 53, 53, 65, 34, 55])

# %%
import statistics

# %%
mean=statistics.mean(test)
print("mean:",mean)
# Out:
# mean: 49

# %%
variance=statistics.variance(test)
print("variance:",variance)
# Out:
# variance: 126

# %%
median=statistics.median(test)
print("median:",median)
# Out:
# median: 50.0

# %%
mode=statistics.mode(test)
print("mode:", mode)
# Out:
# mode: 46

# %%
Standard_Deviation=np.std(test)
print("standard_deviation",Standard_Deviation)
# Out:
# standard_deviation 11.228144592941435

# %%
size=10000
values=np.random.normal(mean,Standard_Deviation,size)

# %%
plt.hist(values,100)
# plotting mean 
plt.axvline(values.mean(),color='b',linestyle="--",linewidth=2)
plt.show()

# %%
roll=randint(1,6,100)            
print(roll)
# Out:
# [3 5 3 4 1 5 5 4 4 4 2 4 5 3 4 2 1 5 4 4 3 3 4 4 4 3 2 2 2 5 1 1 1 3 3 2 2
#  1 2 4 3 3 4 3 4 4 1 1 5 2 1 1 3 5 3 2 4 1 1 5 5 3 5 2 3 3 2 4 1 2 5 3 1 2
#  1 1 3 5 2 5 5 3 3 1 2 4 1 4 5 4 3 2 4 3 2 5 4 2 1 5]

# %%
from numpy import mean
means=[mean(randint(1,6,100)) for _ in range(1000)]
plt.hist(means)
plt.show()

# %%
mean(means)
# Out:
# 3.0023999999999997

# %%
import seaborn as sns
sns.displot(data=means, kind="kde")

# %%
data=randint(1,6,1000000) 
data
statistics.mean(data)
# Out:
# 3

# %%
import sklearn

# %%
import numpy as np

np.random.seed(100)

#create array of 50 random integers between 0 and 10
x = np.random.randint(0, 10, 50)


np.corrcoef(x,x)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
#create a positively correlated array with some random noise
y = x + np.random.randint(10, 20, 50)

#calculate the correlation between the two arrays
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.75618923],
#        [0.75618923, 1.        ]])

# %%
# plotting the data
plt.scatter(x, y)

# %%
ax = sns.heatmap(np.corrcoef(x,y), annot=True)
